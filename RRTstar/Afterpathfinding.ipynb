# %%
import numpy
import matplotlib.pyplot as plot
import matplotlib.colors as plot_colors

# %%
no_moves = 256
no_generations = 128
no_chromosomes = 100

dna_size = no_moves * 2
dna_bound = [0, 2]

cross_rate = 0.9
mutation_rate = 0.0001

obstacle_line = numpy.array([[5, 4], [5, 9]])

plot_config_toolbar = "None"
plot_config_font = {'family': 'DejaVu Sans', 'weight': 'bold', 'size': 7}

class GeneticAlgorithm(object):
    def __init__(self, dna_size, dna_bound, cross_rate, mutation_rate, no_chromosomes):
        self.dna_size = dna_size
        self.dna_bound = dna_bound
        self.cross_rate = cross_rate
        self.mutation_rate = mutation_rate
        self.no_chromosomes = no_chromosomes

        self.generation = numpy.random.randint(*dna_bound, size = (no_chromosomes, dna_size))

    def dna_to_product(self, no_moves, point_a):
        dna = self.generation
        generation = (dna - 0.5) / 2
        generation[:, 0], generation[:, no_moves] = point_a[0], point_a[1]
        lines_x = numpy.cumsum(generation[:, :no_moves], axis = 1)
        lines_y = numpy.cumsum(generation[:, no_moves:], axis = 1)
        return lines_x, lines_y

    def get_fitness(self, lines_x, lines_y, point_b, obstacle_line):
        distance_to_goal = numpy.sqrt((point_b[0] - lines_x[:, -1]) ** 2 + (point_b[1] - lines_y[:, -1]) ** 2)
        fitness = numpy.power(1 / (distance_to_goal + 1), 2)
        points = (lines_x > obstacle_line[0, 0] - 0.5) & (lines_x < obstacle_line[1, 0] + 0.5)
        y_values = numpy.where(points, lines_y, numpy.zeros_like(lines_y) - 100)
        bad_lines = ((y_values > obstacle_line[0, 1]) & (y_values < obstacle_line[1, 1])).max(axis = 1)
        fitness[bad_lines] = 1e-6
        return fitness

    def select(self, fitness):
        index = numpy.random.choice(numpy.arange(self.no_chromosomes), size = self.no_chromosomes, replace = True, p = fitness / fitness.sum())
        return self.generation[index]

    def crossover(self, parent, generation):
        if numpy.random.rand() < self.cross_rate:
            i_ = numpy.random.randint(0, self.no_chromosomes, size = 1)  # select another individual from generation
            cross_points = numpy.random.randint(0, 2, self.dna_size).astype(numpy.bool)  # choose crossover points
            parent[cross_points] = generation[i_, cross_points] # cross and produce one child
        return parent

    def mutate(self, child):
        for point in range(self.dna_size):
            if numpy.random.rand() < self.mutation_rate:
                child[point] = numpy.random.randint(*self.dna_bound)
        return child

    def evolve(self, fitness):
        generation = self.select(fitness)
        generation_copy = generation.copy()
        for parent in generation:
            child = self.crossover(parent, generation_copy)
            child = self.mutate(child)
            parent[:] = child
        self.generation = generation

class Line(object):
    def __init__(self, no_moves, point_b, point_a, obstacle_line):
        self.no_moves = no_moves
        self.point_b = point_b
        self.point_a = point_a
        self.obstacle_line = obstacle_line

        plot.ion()
        plot.rcParams['toolbar'] = plot_config_toolbar
        plot.rc('font', **plot_config_font)
        figure = plot.figure()
        figure.canvas.set_window_title('Genetic algorithm 2D-View')

    def plotting(self, lines_x, lines_y):
        plot.cla()
        plot.scatter(*self.point_b, s = 100, c="blue")
        plot.scatter(*self.point_a, s = 100, c="red")
        plot.plot(self.obstacle_line[:, 0], self.obstacle_line[:, 1], lw=3, c='black')
        plot.plot(lines_x.T, lines_y.T, c=(plot_colors.to_rgba("grey", alpha=0.5)))
        plot.xlim((-5, 15))
        plot.ylim((-5, 15))
        plot.pause(0.02)

def main():
    try:
        print("Input starting point(x, y), each number in new line.")
        x = float(input())
        y = float(input())
        point_a = [x, y]

        print("Input ending point(x, y), each number in new line.")
        x = float(input())
        y = float(input())
        point_b = [x, y]
    except:
        point_a = [0, 5]
        point_b = [10, 7.5]
        print("Wrong!")

    algorithm = GeneticAlgorithm(dna_size = dna_size, dna_bound = dna_bound, cross_rate = cross_rate, mutation_rate = mutation_rate, no_chromosomes = no_chromosomes)

    line = Line(no_moves = no_moves, point_b = point_b, point_a = point_a, obstacle_line = obstacle_line)

    for generation in range(no_generations):
        x, y = algorithm.dna_to_product(no_moves, point_a)
        fitness = algorithm.get_fitness(x, y, point_b, obstacle_line)
        algorithm.evolve(fitness)

        print('generation_', generation, ' | max(fitness): ', fitness.max())
        line.plotting(x, y)

    plot.ioff()
    plot.show()
  
if __name__== "__main__":
  main()
# Out:
# Input starting point(x, y), each number in new line.
# (1,2)
# Wrong input! Defaults are loaded.
# generation_ 0  | max(fitness):  0.06744963495484023
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:80: MatplotlibDeprecationWarning:
# The set_window_title function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use manager.set_window_title or GUI-specific methods instead.
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 1  | max(fitness):  0.07068296456034447
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 2  | max(fitness):  0.13053920422250795
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 3  | max(fitness):  0.3119016527346512
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 4  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 5  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 6  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 7  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 8  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 9  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 10  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 11  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 12  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 13  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 14  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 15  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 16  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 17  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 18  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 19  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 20  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 21  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 22  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 23  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 24  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 25  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 26  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 27  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 28  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 29  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 30  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 31  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 32  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 33  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 34  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 35  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 36  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 37  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 38  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 39  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 40  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 41  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 42  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 43  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 44  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 45  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 46  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 47  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 48  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 49  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 50  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 51  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 52  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 53  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 54  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 55  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 56  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 57  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 58  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 59  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 60  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 61  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 62  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 63  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 64  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 65  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 66  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 67  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 68  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 69  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 70  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 71  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 72  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 73  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 74  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 75  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 76  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 77  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 78  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 79  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 80  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 81  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 82  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 83  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 84  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 85  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 86  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 87  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 88  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 89  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 90  | max(fitness):  0.545819714368591
# ...
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 97  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 98  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 99  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 100  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 101  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 102  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 103  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 104  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 105  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 106  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 107  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 108  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 109  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 110  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 111  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 112  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 113  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 114  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 115  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 116  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 117  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 118  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 119  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 120  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 121  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 122  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 123  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 124  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 125  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 126  | max(fitness):  0.545819714368591
# /Users/marszhang/opt/anaconda3/envs/baseline1/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# generation_ 127  | max(fitness):  0.545819714368591
